# %% [markdown]
# ## **Ülesseadmine**

# %%
# !mkdir photos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

from datapointloss.functions import brier_curve, curve_areas, loss_bins, brier, cross_entropy, default
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-49e36a89576a> in <module>
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 from datapointloss.functions import brier_curve, curve_areas, loss_bins, brier, cross_entropy, default
#
# ModuleNotFoundError: No module named 'datapointloss'

# %% [markdown]
# ## **Brier'i kõverad**

# %%
x=np.linspace(0.000,1.000,1001).tolist()

# %%
## Data
y_true = [1]
p_pred = [0.8]

## Plot figure 
plt.figure(figsize=(8,5))

## Plot curve for all the data.
y = brier_curve(y_true, p_pred, w=brier)
plt.plot(x, y, label='whole curve', linewidth=3)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.xlabel('Hindade suhe C', fontsize=16)
plt.ylabel('2 * Keskmine hind',  fontsize=16)

plt.savefig('photos/1_brier_curve.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e7d00e55178b> in <module>
#      16 plt.ylabel('2 * Keskmine hind',  fontsize=16)
#      17
# ---> 18 plt.savefig('photos/1_brier_curve.png')
#
# ~/opt/anaconda3/envs/loputoo/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     935 def savefig(*args, **kwargs):
#     936     fig = gcf()
# --> 937     res = fig.savefig(*args, **kwargs)
#     938     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     939     return res
#
# ~/opt/anaconda3/envs/loputoo/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2960                 patch.set_edgecolor('none')
#    2961
# -> 2962         self.canvas.print_figure(fname, **kwargs)
#    2963
#    2964         if transparent:
#
# ...

# %%
## Data
y_true = [0]
p_pred = [0.3]

## Plot figure 
plt.figure(figsize=(8,5))

## Plot curve for all the data.
y = brier_curve(y_true, p_pred, w=brier)
plt.plot(x, y, label='whole curve', linewidth=3)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.xlabel('Hindade suhe C', fontsize=16)
plt.ylabel('2 * Keskmine hind',  fontsize=16)

plt.savefig('photos/0_brier_curve.png')

# %%
## Data
y_true = [0, 0, 0, 1, 1]
p_pred = [0.1, 0.2, 0.3, 0.75, 0.8]

## Plot figure 
plt.figure(figsize=(8,5))

## Plot curve for all the data.
y = brier_curve(y_true, p_pred)
plt.plot(x, y, label='whole curve', linewidth=3)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.xlabel('Hindade suhe C', fontsize=16)
plt.ylabel('Keskmine hind',  fontsize=16)

plt.savefig('photos/brier_curve.png')

# %% [markdown]
# ## **Ristentroopia kõverad**

# %%
## Data
y_true = [0, 0, 0, 1, 1]
p_pred = [0.1, 0.2, 0.3, 0.75, 0.8]

## Plot figure 
plt.figure(figsize=(8,5))

def cross_entropy(c):
    if c == 0 or c==1:
        return 1000
    return 1 / (c * (1-c))

## Plot curve for all the data.
y = brier_curve(y_true, p_pred, w=cross_entropy)
plt.plot(x, y, label='whole curve', linewidth=3)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.xlabel('Hindade suhe C', fontsize=16)
plt.ylabel('1\(c(1-c)) * Keskmine hind',  fontsize=16)

plt.savefig('photos/crossentropy_distorted_curve.png')

# %%
x = np.linspace(0.000,1.000, 1001).tolist()
    
## Data
y_true = [0, 0, 0, 1, 1]
p_pred = [0.1, 0.2, 0.3, 0.75, 0.8]

## Plot figure 
plt.figure(figsize=(8,5))
plt.gcf().subplots_adjust(bottom=0.15)

## Plot curve for all the data.
y = brier_curve(y_true, p_pred)
plt.plot(x, y, label='whole curve', linewidth=3)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.xscale('logit')

plt.xlabel('Hindade suhe C', fontsize=16)
plt.ylabel('Keskmine hind',  fontsize=16)

plt.savefig('photos/crossentropy_curve.png')

# %% [markdown]
# ## **Brier'i kõverate andmepunktide pindalad**

# %%
## Plot figure 
plt.figure(figsize=(8,5))
## Data
y_true = [0, 0, 0, 1, 1]
p_pred = [0.1, 0.2, 0.3, 0.75, 0.8]

## Kõver kõikide punktide jaoks.
y = brier_curve(y_true, p_pred, w=brier)
plt.plot(x, y, label='whole curve', linewidth=3, color='tab:red')

## Data
y_true = [0, 0, 0, 0, 0]
p_pred = [0, 0, 0.3, 0, 0]

## Kõver ühe punkti jaoks.
y = brier_curve(y_true, p_pred, w=brier)
plt.plot(x, y, label='whole curve', linewidth=3, color='tab:green')

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.xlabel('Hindade suhe C', fontsize=16)
plt.ylabel('2 * Keskmine hind',  fontsize=16)

plt.savefig('photos/one_point_brier_curve.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-d0dafc02c294> in <module>
#      23 plt.ylabel('2 * Keskmine hind',  fontsize=16)
#      24
# ---> 25 plt.savefig('photos/one_point_brier_curve.png')
#
# ~/opt/anaconda3/envs/loputoo/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     935 def savefig(*args, **kwargs):
#     936     fig = gcf()
# --> 937     res = fig.savefig(*args, **kwargs)
#     938     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     939     return res
#
# ~/opt/anaconda3/envs/loputoo/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2960                 patch.set_edgecolor('none')
#    2961
# -> 2962         self.canvas.print_figure(fname, **kwargs)
#    2963
#    2964         if transparent:
#
# ...

# %%
## Plot figure 
plt.figure(figsize=(8,5))
## Data
X_test = pd.DataFrame(data={'col1': [0, 0, 0, 0, 0], 'col2': [1, 1, 1, 1, 1]})
y_true = [0, 0, 0, 1, 1]
p_pred = [0.1, 0.2, 0.3, 0.75, 0.8]

## Kõver kõikide punktide jaoks.
y = brier_curve(y_true, p_pred, w=brier)
plt.plot(x, y, label='whole curve', linewidth=3, color='tab:red')

## Data
y_true = [0, 0, 0, 0, 0]
p_pred = [0, 0, 0.3, 0, 0]

## Kõver ühe punkti jaoks.
y = brier_curve(y_true, p_pred, w=brier)
plt.plot(x, y, label='whole curve', linewidth=3, color='tab:green')

## Data
y_true = [0, 0, 0, 0, 0]
p_pred = [0, 0.2, 0, 0, 0]

## Kõver ühe punkti jaoks.
y = brier_curve(y_true, p_pred, w=brier)
plt.plot(x, y, label='whole curve', linewidth=3, color='tab:orange')

## Data
y_true = [0, 0, 0, 0, 0]
p_pred = [0.1, 0, 0, 0, 0]

## Kõver ühe punkti jaoks.
y = brier_curve(y_true, p_pred, w=brier)
plt.plot(x, y, label='whole curve', linewidth=3, color='tab:blue')

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.xlabel('Hindade suhe C', fontsize=16)
plt.ylabel('2 * Keskmine hind',  fontsize=16)

plt.savefig('photos/pos_points_brier_curve.png')

# %%
## Plot figure 
plt.figure(figsize=(8,5))
## Data
y_true = [0, 0, 0, 1, 1]
p_pred = [0.1, 0.2, 0.3, 0.75, 0.8]

## Kõver kõikide punktide jaoks.
y = brier_curve(y_true, p_pred, w=brier)
plt.plot(x, y, label='whole curve', linewidth=3, color='tab:red')

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.xlabel('Hindade suhe C', fontsize=16)
plt.ylabel('2 * Keskmine hind',  fontsize=16)

curve_areas(X_test, np.array(y_true), np.array(p_pred), targets=[0], w=brier)

plt.savefig('photos/areas_brier_curve.png')

# %%
## Plot figure 
plt.figure(figsize=(8,5))
## Data
y_true = [0, 0, 0, 1, 1]
p_pred = [0.1, 0.2, 0.3, 0.75, 0.8]

## Kõver kõikide punktide jaoks.
y = brier_curve(y_true, p_pred, w=brier)
plt.plot(x, y, label='whole curve', linewidth=3, color='tab:red')

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.xlabel('Hindade suhe C', fontsize=16)
plt.ylabel('2 * Keskmine hind',  fontsize=16)

curve_areas(X_test, np.array(y_true), np.array(p_pred), targets=[0,1], w=brier)

plt.savefig('photos/all_areas_brier_curve.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d0dae960c537> in <module>
#      15 plt.ylabel('2 * Keskmine hind',  fontsize=16)
#      16
# ---> 17 curve_areas(X_test, np.array(y_true), np.array(p_pred), targets=[0,1], w=brier)
#      18
#      19 plt.savefig('photos/all_areas_brier_curve.png')
#
# NameError: name 'X_test' is not defined

# %%
y_true = [0, 0, 0, 1, 1]
p_pred = [0.1, 0.2, 0.3, 0.75, 0.8]

plt.figure(figsize=(8,5))

loss_bins(np.array(y_true), np.array(p_pred), w=brier, target=0, bins=10)

plt.xlabel('Positiivse klassi tõenäosus', fontsize=18)
plt.ylabel('Panustatud kadu', fontsize=18)

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.show()
